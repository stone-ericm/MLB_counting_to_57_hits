# %%
from pybaseball import statcast
from pybaseball import playerid_lookup
import pandas as pd
from pybaseball import cache
cache.enable()

pd.set_option("display.max_columns", None)

# find David Ortiz's player id (mlbam_key)
# playerid_lookup('ortiz','david')

# get all available data
# data = statcast_batter('2008-04-01', '2008-04-01', player_id = 120074)

# get data for August 16th, 2014
data = statcast('2017-07-04')

data
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:06<00:00,  6.91s/it]
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3201         FC 2017-07-04           91.1          -0.79           6.04
# 3233         FC 2017-07-04           92.3          -1.04           5.86
# 3328         FC 2017-07-04           91.0          -1.32           5.83
# 3483         FF 2017-07-04           95.6          -1.14           5.98
# 3540         FC 2017-07-04           91.2          -1.24           5.94
# ...         ...        ...            ...            ...            ...
# 3943         FF 2017-07-04           93.3           1.18           6.38
# 4066         SL 2017-07-04           88.6           1.19           6.49
# 4141         SL 2017-07-04           89.7           1.11           6.48
# 4326         CU 2017-07-04           73.4           0.81           6.66
# 4353         FF 2017-07-04           92.7           1.08           6.43
#
# ...

# %%
data.sort_index()
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0            FF 2017-07-04           92.6            1.1           6.27
# 1            SL 2017-07-04           91.5          -1.64           6.37
# 2            FF 2017-07-04           91.9            1.2           6.25
# 3            FF 2017-07-04           92.2           1.15           6.33
# 4            FF 2017-07-04           96.2           -1.8           6.28
# ...         ...        ...            ...            ...            ...
# 4445         CU 2017-07-04           77.9           0.61            5.9
# 4446         FF 2017-07-04           95.0          -1.82           6.57
# 4447         FF 2017-07-04           93.1          -1.47            6.4
# 4448         FF 2017-07-04           91.4           1.86           6.21
# 4449         FT 2017-07-04           93.2          -1.61           6.25
#
#            player_name  batter  pitcher     events              description  \
# ...

# %%
from pybaseball import batting_stats

batting_stats(2019)
# Out:
#       IDfg  Season              Name Team  Age    G   AB   PA    H   1B  ...  \
# 1    10155    2019        Mike Trout  LAA   27  134  470  600  137   63  ...
# 2    17678    2019      Alex Bregman  HOU   25  156  554  690  164   84  ...
# 0    11477    2019  Christian Yelich  MIL   27  130  489  580  161   85  ...
# 4    15998    2019    Cody Bellinger  LAD   23  156  558  660  170   86  ...
# 31   12533    2019     Marcus Semien  OAK   28  162  657  747  187  104  ...
# ..     ...     ...               ...  ...  ...  ...  ...  ...  ...  ...  ...
# 102   1744    2019    Miguel Cabrera  DET   36  136  493  549  139  106  ...
# 114   3516    2019       Eric Hosmer  SDP   29  160  619  667  164  111  ...
# 134  13185    2019     Orlando Arcia  MIL   24  152  494  546  110   78  ...
# 115   1177    2019     Albert Pujols  LAA   39  131  491  545  120   75  ...
# 130   9112    2019       Khris Davis  OAK   31  133  481  533  106   72  ...
#
# ...

# %%
from bs4 import BeautifulSoup
from requests_html import HTMLSession
import pandas as pd

html_session = HTMLSession()

URL= 'https://widgets.sports-reference.com/wg.fcgi?css=1&site=br&url=%2Fboxes%2FLAN%2FLAN202107210.shtml&div=div_play_by_play'

r = html_session.get(URL)
soup = BeautifulSoup(r.content, 'html.parser')
table = soup.find(id="play_by_play")

table = pd.read_html(URL)

# %%
table[0]
# Out:
#                                                    Inn  \
# 0    Top of the 1st, Giants Batting, Tied 0-0, Dodg...
# 1                                                   t1
# 2                                                   t1
# 3                                                   t1
# 4                                                   t1
# ..                                                 ...
# 115                                                NaN
# 116                                                 b9
# 117                                                 b9
# 118                                                 b9
# 119                                                NaN
#
#                                                  Score  \
# 0    Top of the 1st, Giants Batting, Tied 0-0, Dodg...
# 1                                                  0-0
# 2                                                  0-0
# 3                                                  0-0
# ...
